# %%
9
# Out:
# 9

# %%
a = 3
b = 4
print(a+b)
# Out:
# 7

# %%
print("fsdcvcvx" + a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print("fsdcvcvx" + a)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print("fsdcvcvx" + str(a))
# Out:
# fsdcvcvx3

# %%
x = 1.345
x
# Out:
# 1.345

# %%
x = 5
print(type(x))

y = 1.234
print(type(y))

z = x + y
type(z)
# Out:
# <class 'int'>
# <class 'float'>
# float

# %%
type(str(z))
# Out:
# str

# %%
b1 = True
b2 = False

type(b2)
# Out:
# bool

# %% [markdown]
# ## Strings

# %%
name = "my name is joey's tribiani"
print(type(name))
name
# Out:
# <class 'str'>
# "my name is joey's tribiani"

# %%
str_ = "tribiani"
str_
# Out:
# 'tribiani'

# %% [markdown]
# ## Complex

# %% [markdown]
# Created using the form x+yj format, x being real and y being imaginary numbers

# %%
j = 1.0-2.0j
j
# Out:
# (1-2j)

# %%
type(j)
# Out:
# complex

# %% [markdown]
# ## Variables

# %%
tenth = 10
tenth = 15
tenth
# Out:
# 15

# %% [markdown]
# Dynamic typing: python automatically decides the type of data assigned to a variable.

# %% [markdown]
# ## Str Typing

# %%
print("str" + str(1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 print("str" + str(1))
#
# TypeError: 'str' object is not callable

# %%
# Opearators in python

a = 10
b = 3
print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a % b)
print(a // b)
print(a ** b)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 1
# 3
# 1000

# %%
# Comparison

print(a == b)
print(a != b)
print(a < b)
print(a > b)
print(a <= b)
print(a >= b)
# Out:
# False
# True
# False
# True
# False
# True

# %%
x = True
y = False
print(x and y)
print(x or y)
print(not y)
# Out:
# False
# True
# True

# %%
# assignment operations

x = 5
x = +5
x = -5

x += 5 #x = x + 5
x -= 5 #x = x - 5
x *= 3 #x = x * 3
print(x)
# Out:
# -15

# %%
name = input("Enter your name: ")
print("Hello", name)
print(type(name))
# Out:
# Enter your name:  tej
# Hello tej
# <class 'str'>

# %%
# f string

age = 48
type(age)
year = 1978

x = f"I am {age} years of old, born in {year}"

print(x)
# Out:
# I am 48 years of old, born in 1978

# %%
# .format

language = "python"
subject = "programming"

print("I love {}, my subject is {}".format(language, subject))
# Out:
# I love python, my subject is programming

# %% [markdown]
# ## Branching (if/elif/else)

# %%
i = 4

if (i < 3):
    print("less than 3")
    if (i<2):
        print("sdds")
elif i<5:
    print("less than 5")
elif i < 12:
    print("too low")
else:
    print("5 or more")
# Out:
# < 5
