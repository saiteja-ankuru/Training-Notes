# %% [markdown]
# ## Strings and List Objects

# %% [markdown]
# ## Strings

# %% [markdown]
# Strings store the information in the form of text. It is written in between quotes('') or double quotes("")

# %%
'hello'
# Out:
# 'hello'

# %%
'This is a string'
# Out:
# 'This is a string'

# %%
"string can written between double quotes"
# Out:
# 'string can written between double quotes'

# %%
'I'm using single quote string, but gives error'
# Out:
#   Cell In[4], line 1
#     'I'm using single quote string, but gives error'
#                                                    ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"Now, I'm using string but this time with double quotes, so no error"
# Out:
# "Now, I'm using string but this time with double quotes, so no error"

# %%
print("use \n to print new line")
# Out:
# use
#  to print new line

# %% [markdown]
# ## String Functions

# %%
## String length
len("hello")
# Out:
# 5

# %%
# string indexing

s = "Hello"
print(s)
# Out:
# Hello

# %%
s[0]
# Out:
# 'H'

# %%
s[-1]
# Out:
# 'o'

# %%
s[0:]
# Out:
# 'Hello'

# %%
s[1:3]
# Out:
# 'el'

# %%
for i in range(len(s)):
    print("index", i, ":", s[i])
    print(f"index {i}: {s[i]}")
# Out:
# index 0 : H
# index 0: H
# index 1 : e
# index 1: e
# index 2 : l
# index 2: l
# index 3 : l
# index 3: l
# index 4 : o
# index 4: o

# %%
s[-1:]
# Out:
# 'o'

# %%
s.upper()
# Out:
# 'HELLO'

# %%
s.lower()
# Out:
# 'hello'

# %%
s = "Hello World"

# %%
s.split()
# Out:
# ['Hello', 'World']

# %%
s.split('W')
# Out:
# ['Hello ', 'orld']

# %%
s.count('o')
# Out:
# 2

# %%
s.find('o')
# Out:
# 4

# %%
'hello\thi'.expandtabs()
# Out:
# 'hello   hi'

# %%
s='hello'
s.isalnum()
# Out:
# True

# %%
s.isalpha()
# Out:
# True

# %%
s.islower()
# Out:
# True

# %%
s.isspace()
# Out:
# False

# %%
s.istitle()
# Out:
# False

# %%
s="Hello"
s.istitle()
# Out:
# True

# %%
s.isupper()
# Out:
# False

# %% [markdown]
# ## Lists

# %% [markdown]
# Stores different type of elements, strings, list of lists, tuples, dictionaries. Lists are indicated with [].
# Lists are mutable and can be changed or reordered.

# %%
my_list = ['1','2,', 3, 'True', False]

# %%
my_list
# Out:
# ['1', '2,', 3, 'True', False]

# %%
len(my_list)
# Out:
# 5

# %%
my_list[2]
# Out:
# 3

# %%
my_list[-1]
# Out:
# False

# %%
my_list[::-1]
# Out:
# [False, 'True', 3, '2,', '1']

# %%
my_list[1:4]
# Out:
# ['2,', 3, 'True']

# %%
my_list = my_list + ['add a number']

# %%
my_list
# Out:
# ['1', '2,', 3, 'True', False, 'add a number']

# %%
my_list.append('hi')
my_list
# Out:
# ['1', '2,', 3, 'True', False, 'add a number', 'hi']

# %%
my_list.pop()
# Out:
# 'hi'

# %%
my_list
# Out:
# ['1', '2,', 3, 'True', False, 'add a number']

# %%
my_list.reverse()

# %%
nums = [1, 2, 7, 3, 9, 8, 5]

# %%
nums.sort()
nums
# Out:
# [1, 2, 3, 4, 5, 7, 8, 9]

# %% [markdown]
# ## Nesting lists

# %% [markdown]
# nesting lists is list of lists.

# %%
lst1 = [1,2,3]
lst2 = [4,5,6]
lst3 = [7,8,9]

matrix = [lst1, lst2, lst3]

# %%
matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
matrix[1][1]
# Out:
# 5

# %%
nums.index(5)
# Out:
# 4

# %%
nums.remove(4)

# %%
nums
# Out:
# [1, 2, 3, 5, 7, 8, 9]
